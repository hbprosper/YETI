# %% [markdown]
# # Deep Neural Networks - exercise 02
#  >__Created__:  2018 Harrison B. Prosper
#
#
# ### Neural Networks
# A neural network (NN) is a highly non-linear function. The functional form of a single layer NN with $I$ inputs and $J$ outputs is
#
# $$y_{j}(x) = f\left(b_{j} + \sum_{i=1}^I w_{ji} \, x_i\right),\quad j = 1,\cdots,J,$$
# which in matrix notation is
# $$\mathbf{y} = f\left(\mathbf{b} + \mathbf{w} \, \mathbf{x}\right),$$
# where $f(*)$ is a non-linear function to be applied *element-wise* to its matrix argument. Popular examples of $f(*)$ are
# \begin{align*}
#     f(z) & = \tanh{z},\\
#     f(z) & = \max(0, z) \quad\textrm{reLU function}.
# \end{align*}
#
# Consider a neural network with $I$ inputs, $x_{i}, i = 1, \cdots, I$, a single hidden layer with $H$ nodes, and $K$ outputs $y_{k}(x), k = 1, \cdots, K$. Such a network is said to be *shallow* with structure $(I, H, K)$. The functional form is
#
# $$y = g(\mathbf{b}_1 + \mathbf{w}_1 \, f(\mathbf{b}_0 + \mathbf{w}_0 \, \mathbf{x})),$$
#
# where the subscripts label the layers, and, usually, the output function $g$ differs from $f$. For regression,  $g$ is
# the $identity$. For 2-class (i.e., binary) classification it is usually the $logistic$ function
#
# $$g(z) = \frac{1}{1 + \exp(-z)},$$
#
# while for multi-class classification one typically uses the $softwmax$ function
#
# $$y_j = g(z_j) = \frac{\exp(z_j)}{\sum_{k=1}^K \exp(z_k)}.$$
#
# For the special case of a single output network, $\mathbf{b}_1$ becomes a scalar $b$ and $\mathbf{w}_1$
# is a column matrix.
#
# ### Deep Neural Networks
# A feed forward deep neural network (DNN) contains two or more hidden layers
# compounded recursively. For example, a DNN with two hidden layers has the functional form
#
# $$y = g(\mathbf{b}_2 + \mathbf{w}_2 \, f(\mathbf{b}_1 + \mathbf{w}_1 \, f(\mathbf{b}_0 + \mathbf{w}_0 \, \mathbf{x}))).$$
#
# The matrices can be sparse or dense. Dense matrices yield fully-connected neural networks.
#
# ### Exercise
#   1. Build a deep network, using __MLPRegression__, to predict wine quality.
#   1. Vary the number of layers and nodes/layer.

# %%
import os, sys
import pandas as pd
import numpy as np

from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor
from sklearn.externals import joblib

import matplotlib as mp
import matplotlib.pyplot as plt
import pylab as pl

# %matplotlib inline

# %%
# update fonts
FONTSIZE = 20
font = {'family' : 'sans-serif',
        'weight' : 'normal',
        'size'   : FONTSIZE}

mp.rc('font', **font)

# %% [markdown]
# ### Load data into memory

# %%
wine  = pd.read_csv('../../datasets/whitewine.csv')
inputs= wine.keys().tolist()[:-1]
wine[0:10]
# Out:
#    acetic  citric  suger   salt  SO2free  SO2tota    pH  sulfate  alcohol  \
# 0   0.180    0.33    1.4  0.029     35.0    138.0  3.36     0.60     11.5
# 1   0.685    0.21    9.5  0.070     33.0    172.0  3.00     0.55      9.1
# 2   0.210    0.28    2.4  0.056     49.0    159.0  3.02     0.47      8.8
# 3   0.250    0.13   17.2  0.036     49.0    219.0  2.96     0.46      9.7
# 4   0.420    0.23    8.8  0.054     42.0    215.0  3.02     0.58      9.2
# 5   0.240    0.15    7.1  0.043     32.0    134.0  3.24     0.48      9.9
# 6   0.250    0.37    1.0  0.043     10.0     80.0  3.08     0.38     11.4
# 7   0.140    0.32    1.1  0.022     48.0    116.0  3.04     0.67     10.0
# 8   0.310    0.26    7.3  0.050     37.0    157.0  3.09     0.43      9.0
# 9   0.410    0.18    3.5  0.027     23.0    109.0  3.34     0.54     12.8
#
#    quality
# 0      0.7
# 1      0.6
# 2      0.8
# 3      0.5
# 4      0.6
# 5      0.6
# 6      0.5
# 7      0.6
# 8      0.5
# 9      0.8

# %% [markdown]
# ### Plot wine quality distribution
# We see that the data are very unbalanced. Therefore, we should expect some difficulty in building a good wine quality predictor, even assuming that we have the correct input variables.

# %%
def plotVariable(df, name, x_label, x_range=(0.05, 1.05), nbins=10, kolor='blue', fgsize=(12, 6)):
    # set size of figure
    plt.figure(figsize=fgsize)
    c, b, _ = plt.hist(df[name],
                       bins=nbins, 
                       color=kolor,
                       alpha=0.3,
                       log=False,
                       range=x_range, 
                       normed=True)

    plt.xlim([0, 1])
    plt.ylim([0, 5])
    plt.xlabel(x_label)
    plt.savefig("02_wine_%s.png" % name)
    plt.show()
    
    # get mid-point of each of n bins
    # b[1:] = b[1], b[2],..., b[n]
    # b[:-1]= b[0], b[1],..., b[n-1]
    m = (b[1:] + b[:-1]) / 2
    return (c, m)

# %%
c, m = plotVariable(wine, 'quality', 'wine quality')

# %%
def plotVariables(wine, variables, fgsize=(10, 10)):
    cmap = plt.cm.rainbow
    norm = mp.colors.Normalize(vmin=min(wine.quality), 
                               vmax=max(wine.quality))
    

    pd.scatter_matrix(wine[variables], 
                      c=cmap(norm(wine.quality)),
                      alpha=0.9,
                      marker='o',
                      figsize=fgsize)
    plt.savefig("02_wine_variables.png")
    plt.show()

# %%
plotVariables(wine[:500], 
              variables=['acetic', 'pH', 'SO2tota', 'alcohol'], 
              fgsize=(10, 10))

# %% [markdown]
# ### Train, validation, and test sets
# There is some confusion in terminology regarding validation and test samples (or sets). We shall adhere to these defintions (see https://machinelearningmastery.com/difference-test-validation-datasets/):
#
#   * __Training Dataset__: The sample of data used to fit the model.
#   * __Validation Dataset__: The sample of data used to provide an unbiased evaluation of a model fit on the training dataset while tuning model hyperparameters. The evaluation becomes more biased as skill on the validation dataset is incorporated into the model configuration.
#   * __Test Dataset__: The sample of data used to provide an unbiased evaluation of a final model fit on the training dataset.
#
# The validation set will be some small fraction of the training set and will be used to decide when to stop the training.

# %%
test_fraction  = 0.20
train_data, test_data = train_test_split(wine, test_size=test_fraction)

print('train set size:      %4d' % train_data.shape[0])
print('test set size:       %4d' % test_data.shape[0])
# Out:
# train set size:      3918
# test set size:        980

# %% [markdown]
# ### Prepare data for training/validation/testing

# %%
def standardize_data(train_data, test_data, names):
    scaler  = StandardScaler()
    scaler.fit(train_data[names])
    
    X_train = scaler.transform(train_data[names])
    y_train = np.array(train_data['quality'])
    
    X_test  = scaler.transform(test_data[names])
    y_test  = np.array(test_data['quality'])
    return (X_train, X_test, y_train, y_test, scaler)

# %%
X_train, X_test, y_train, y_test, scaler = standardize_data(train_data, test_data, inputs)

# %% [markdown]
# ### Define function space
# A particular choice of neural network architecture, be it deep, convolutional, recurrent, etc., defines the space of possible functions that can be accessed via training. If you get poor results, it could be because you have insufficient training data, or perhaps your function space does not contain a function that is a good approximation to the desired function, or it could be that your training algorithm is unable to locate the desired function within your function space, or any combination of these.

# %%
# Stop training when validation score is not improving. 
dnn = MLPRegressor(hidden_layer_sizes=(21, 10), 
                    max_iter=500, 
                    alpha=1e-3,
                    solver='adam',
                    activation='relu',
                    verbose=1, 
                    tol=1e-8, 
                    warm_start=False,
                    random_state=1)

# %% [markdown]
# ### Choose a function, aka train a regressor!

# %%
print "*** TRAINING ***"
dnn.fit(X_train, y_train)
       
print
print("Training set score: %10.4f" % dnn.score(X_train, y_train))      
print("Test set score:     %10.4f" % dnn.score(X_test,  y_test))

filename = '02_wine_dnn.pkl'
print "save to %s" % filename
joblib.dump(dnn, filename)
# Out:
# *** TRAINING ***
# Iteration 1, loss = 0.27681333
# Iteration 2, loss = 0.08574817
# Iteration 3, loss = 0.04536486
# Iteration 4, loss = 0.03368802
# Iteration 5, loss = 0.02661212
# Iteration 6, loss = 0.02184355
# Iteration 7, loss = 0.01846313
# Iteration 8, loss = 0.01593631
# Iteration 9, loss = 0.01394700
# Iteration 10, loss = 0.01241442
# Iteration 11, loss = 0.01115568
# Iteration 12, loss = 0.01013132
# Iteration 13, loss = 0.00930889
# Iteration 14, loss = 0.00862901
# Iteration 15, loss = 0.00804351
# Iteration 16, loss = 0.00753502
# Iteration 17, loss = 0.00708819
# Iteration 18, loss = 0.00670389
# Iteration 19, loss = 0.00633533
# Iteration 20, loss = 0.00602034
# Iteration 21, loss = 0.00572891
# Iteration 22, loss = 0.00549671
# Iteration 23, loss = 0.00528195
# Iteration 24, loss = 0.00508002
# Iteration 25, loss = 0.00490046
# Iteration 26, loss = 0.00474691
# Iteration 27, loss = 0.00461279
# Iteration 28, loss = 0.00447976
# Iteration 29, loss = 0.00437744
# Iteration 30, loss = 0.00427524
# Iteration 31, loss = 0.00418856
# Iteration 32, loss = 0.00411002
# Iteration 33, loss = 0.00403448
# Iteration 34, loss = 0.00395035
# Iteration 35, loss = 0.00387898
# Iteration 36, loss = 0.00380790
# Iteration 37, loss = 0.00375040
# Iteration 38, loss = 0.00369927
# Iteration 39, loss = 0.00363760
# Iteration 40, loss = 0.00358102
# Iteration 41, loss = 0.00353113
# Iteration 42, loss = 0.00348632
# Iteration 43, loss = 0.00344578
# Iteration 44, loss = 0.00340116
# Iteration 45, loss = 0.00337419
# Iteration 46, loss = 0.00334107
# Iteration 47, loss = 0.00331318
# Iteration 48, loss = 0.00327092
# Iteration 49, loss = 0.00324677
# Iteration 50, loss = 0.00321493
# Iteration 51, loss = 0.00319164
# Iteration 52, loss = 0.00317413
# Iteration 53, loss = 0.00314232
# Iteration 54, loss = 0.00311709
# Iteration 55, loss = 0.00310764
# Iteration 56, loss = 0.00307836
# Iteration 57, loss = 0.00306213
# Iteration 142, loss = 0.00240976
# Iteration 143, loss = 0.00241630
# Iteration 144, loss = 0.00241834
# Iteration 145, loss = 0.00240622
# Iteration 146, loss = 0.00241554
# Iteration 147, loss = 0.00240697
# Iteration 148, loss = 0.00239862
# Iteration 149, loss = 0.00241293
# Iteration 150, loss = 0.00240298
# Iteration 151, loss = 0.00239824
# Iteration 152, loss = 0.00238998
# Iteration 153, loss = 0.00239092
# Iteration 154, loss = 0.00239736
# Iteration 155, loss = 0.00238867
# Iteration 156, loss = 0.00238734
# Iteration 157, loss = 0.00240384
# Iteration 158, loss = 0.00238528
# Iteration 159, loss = 0.00237950
# Iteration 160, loss = 0.00237621
# Iteration 161, loss = 0.00239305
# Iteration 162, loss = 0.00237489
# Iteration 163, loss = 0.00237049
# Iteration 164, loss = 0.00237518
# Iteration 165, loss = 0.00236759
# Iteration 166, loss = 0.00236819
# Iteration 167, loss = 0.00236685
# Iteration 168, loss = 0.00237163
# Iteration 169, loss = 0.00236883
# Iteration 170, loss = 0.00236813
# Training loss did not improve more than tol=0.000000 for two consecutive epochs. Stopping.
#
# Training set score:     0.4149
# Test set score:         0.2645
# save to 02_wine_dnn.pkl
# ['02_wine_dnn.pkl']

# %% [markdown]
# ### Plot loss curve vs. epochs

# %%
def plotLoss(dnn, ftsize=FONTSIZE):
    y    = dnn.loss_curve_
    x    = np.array(range(len(y)))+1

    ymin = 0.0
    ymax = 1.2*max(y)
    epoch= range(len(y))
    xmin = 0
    xmax = len(x)
    
    # set size of figure
    plt.figure(figsize=(8,4));

    # get axis info
    axes = plt.gca()
    # set axes' limits
    axes.set_xlim(xmin, xmax)
    axes.set_ylim(ymin, ymax)
    
    # annotate axes
    plt.xlabel(r'epoch', fontsize=ftsize)
    plt.ylabel(r'loss',  fontsize=ftsize)
    
    # choose color of points
    plt.plot(x, y, 'b-')
    plt.savefig('02_wine_dnn_loss.png')
    plt.show()

# %%
plotLoss(dnn)

# %% [markdown]
# ### plot results

# %%
def plotResults(dnn, X_test, y_test, 
                xmin=0.35, xmax=0.95, 
                ymin=0.35, ymax=0.95,
                step=0.10,
                ftsize=FONTSIZE):
    
    p = dnn.predict(X_test)
    m = np.arange(xmin, xmax, step)
    
    # set size of figure
    plt.figure(figsize=(10, 8))
    
    counts,ybins,xbins,image = plt.hist2d(y_test, p, bins=(m, m))
    plt.colorbar()
    
    min_count = np.min(counts)
    max_count = np.max(counts)
    mylevels  = np.arange(min_count, max_count, 10)
    
    plt.contour(counts,
                extent=[xbins.min(),xbins.max(),ybins.min(),ybins.max()],
                linewidths=3,
                levels=mylevels)
    
    plt.plot([0,1], [0,1], c='white', lw=3, linestyle='--')
    
    # annotate axes
    plt.xlabel(r'wine quality', fontsize=ftsize)
    plt.ylabel(r'predicted wine quality', fontsize=ftsize)
    plt.xlim([xmin, xmax-step])
    plt.ylim([ymin, ymax-step])
    plt.savefig('02_wine_dnn_results.png')
    plt.show()

# %%
plotResults(dnn, X_test, y_test)
